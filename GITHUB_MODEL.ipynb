# %%
# !pip install azure-ai-inference
# Out:
# Collecting azure-ai-inference
#   Downloading azure_ai_inference-1.0.0b9-py3-none-any.whl.metadata (34 kB)
# Requirement already satisfied: isodate>=0.6.1 in c:\users\admin\appdata\roaming\python\python311\site-packages (from azure-ai-inference) (0.7.2)
# Collecting azure-core>=1.30.0 (from azure-ai-inference)
#   Downloading azure_core-1.38.0-py3-none-any.whl.metadata (47 kB)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\python311\lib\site-packages (from azure-ai-inference) (4.15.0)
# Requirement already satisfied: requests>=2.21.0 in c:\python311\lib\site-packages (from azure-core>=1.30.0->azure-ai-inference) (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\python311\lib\site-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-ai-inference) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\python311\lib\site-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-ai-inference) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\python311\lib\site-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-ai-inference) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\python311\lib\site-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-ai-inference) (2025.10.5)
# Downloading azure_ai_inference-1.0.0b9-py3-none-any.whl (124 kB)
# Downloading azure_core-1.38.0-py3-none-any.whl (217 kB)
# Installing collected packages: azure-core, azure-ai-inference
# Successfully installed azure-ai-inference-1.0.0b9 azure-core-1.38.0
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os
from azure.ai.inference import ChatCompletionsClient
from azure.ai.inference.models import AssistantMessage, SystemMessage, UserMessage
from azure.core.credentials import AzureKeyCredential
import os
from dotenv import load_dotenv

load_dotenv()  # tự tìm file .env cùng thư mục


token = os.getenv("GITHUB_MODEL_API_KEY")
endpoint = "https://models.github.ai/inference"
model_name = "meta/Meta-Llama-3.1-405B-Instruct"

client = ChatCompletionsClient(
    endpoint=endpoint,
    credential=AzureKeyCredential(token),
)

messages = [
    SystemMessage("You are a helpful assistant."),
    UserMessage("What is the capital of France?"),
    AssistantMessage("The capital of France is Paris."),
    UserMessage("What about Spain?"),
]

response = client.complete(messages=messages, model=model_name)

print(response.choices[0].message.content)
# Out:
# The capital of Spain is Madrid.
